# %% [markdown]
# <a href="https://colab.research.google.com/github/ktiwari8760/Movie-Recommendor-System/blob/main/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Movie Recommendor System

# %%
import numpy as np
import pandas as pd

# %%
dataset_credits = pd.read_csv("/content/credits.csv")
dataset_movies = pd.read_csv("/content/tmdb_5000_movies.csv")

# %%
dataset_credits.shape
# Out:
# (4802, 4)

# %%
df = dataset_movies.merge(dataset_credits , on = 'title')

# %%
df.head(1)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                       homepage     id  \
# 0  http://www.avatarmovie.com/  19995
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
#
#   original_title                                           overview  \
# 0         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                               production_companies  ... runtime  \
# 0  150.437577  [{"name": "Ingenious Film Partners", "id": 289...  ...   162.0
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
#
#                        tagline   title vote_average vote_count movie_id  \
# 0  Enter the World of Pandora.  Avatar          7.2      11800    19995
#
# ...

# %%
# We can see that most of the movies are made in english so we can drop it.
df.value_counts("original_language")
# Out:
# original_language
# en    4494
# fr      67
# es      30
# zh      27
# de      27
# hi      19
# ja      15
# it      13
# ko      12
# cn      12
# ru      11
# pt       9
# da       7
# sv       5
# nl       4
# fa       4
# th       3
# he       3
# cs       2
# id       2
# ta       2
# ro       2
# ar       2
# vi       1
# sl       1
# tr       1
# te       1
# xx       1
# pl       1
# ps       1
# el       1
# no       1
# nb       1
# ky       1
# is       1
# hu       1
# af       1
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4786 entries, 0 to 4785
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4786 non-null   int64
#  1   genres                4786 non-null   object
#  2   homepage              1707 non-null   object
#  3   id                    4786 non-null   int64
#  4   keywords              4786 non-null   object
#  5   original_language     4786 non-null   object
#  6   original_title        4786 non-null   object
#  7   overview              4783 non-null   object
#  8   popularity            4786 non-null   float64
#  9   production_companies  4786 non-null   object
#  10  production_countries  4786 non-null   object
#  11  release_date          4785 non-null   object
#  12  revenue               4786 non-null   int64
#  13  runtime               4784 non-null   float64
#  14  spoken_languages      4786 non-null   object
# ...

# %%
# We are going to predict on the basis of cast , crew , movie_id , title , overview , keywords , genres
movies = df[["movie_id" , "keywords" , "genres" , "cast" , "crew" , "title" , "overview"]]

movies.head()
# Out:
#    movie_id                                           keywords  \
# 0     19995  [{"id": 1463, "name": "culture clash"}, {"id":...
# 1       285  [{"id": 270, "name": "ocean"}, {"id": 726, "na...
# 2    206647  [{"id": 470, "name": "spy"}, {"id": 818, "name...
# 3     49026  [{"id": 849, "name": "dc comics"}, {"id": 853,...
# 4     49529  [{"id": 818, "name": "based on novel"}, {"id":...
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# ...

# %%
# We can see that here we have no null values in the data set
movies.isnull().sum()

# If we are having any value we will be dropping it if required

movies = movies.dropna()

# %%
movies.duplicated().sum()
# Out:
# 0

# %%
movies.iloc[:1].genres

# Basically with help of this function and code we make the genres in this format [Action, Adventure, Fantasy, Science Fiction]

movies['genres'] = movies['genres'].apply(get_name)
movies.head(1)
# Out:
#    movie_id                                           keywords  \
# 0     19995  [{"id": 1463, "name": "culture clash"}, {"id":...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
#
#                                                 crew   title  \
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...  Avatar
#
#                                             overview
# 0  In the 22nd century, a paraplegic Marine is di...

# %%
import ast
def get_name(lst):
  lst1 = []
  for i in ast.literal_eval(lst):
    lst1.append(i["name"])

  return lst1

# %%
movies["keywords"] = movies["keywords"].apply(get_name)

# %%
movies.head()
# Out:
#    movie_id                                           keywords  \
# 0     19995  [culture clash, future, space war, space colon...
# 1       285  [ocean, drug abuse, exotic island, east india ...
# 2    206647  [spy, based on novel, secret agent, sequel, mi...
# 3     49026  [dc comics, crime fighter, terrorist, secret i...
# 4     49529  [based on novel, mars, medallion, space travel...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# ...

# %%
import ast
def fetch_charecters(lst):
  lst1 = []
  for i in ast.literal_eval(lst):
    lst1.append(i["character"])

  return lst1

# %%
movies["cast"] = movies["cast"].apply(fetch_charecters)

# %%
movies.head()
# Out:
#    movie_id                                           keywords  \
# 0     19995  [culture clash, future, space war, space colon...
# 1       285  [ocean, drug abuse, exotic island, east india ...
# 2    206647  [spy, based on novel, secret agent, sequel, mi...
# 3     49026  [dc comics, crime fighter, terrorist, secret i...
# 4     49529  [based on novel, mars, medallion, space travel...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
#                                                 cast  \
# 0  [Jake Sully, Neytiri, Dr. Grace Augustine, Col...
# 1  [Captain Jack Sparrow, Will Turner, Elizabeth ...
# 2  [James Bond, Blofeld, Madeleine, M, Lucia, Q, ...
# 3  [Bruce Wayne / Batman, Alfred Pennyworth, Jame...
# ...

# %%
import ast
def fetch_director(lst):
  lst1 = []
  for i in ast.literal_eval(lst):
    if(i["job"] == "Director"):
      lst1.append(i["name"])
      break
  return (lst1)

# %%
movies["crew"] = movies["crew"].apply(fetch_director)

# %%
# def split1(lst):
#   lst2 = []
#   for i in lst:
#     i = i.split()
#     lst2.append(i)
#   return lst2
# lst = ["Hi how are you my name is karting"]
# split1(lst)

movies["overview"] = movies["overview"].apply(lambda x:x.split())

# %%
movies.head()
# Out:
#    movie_id                                           keywords  \
# 0     19995  [culture clash, future, space war, space colon...
# 1       285  [ocean, drug abuse, exotic island, east india ...
# 2    206647  [spy, based on novel, secret agent, sequel, mi...
# 3     49026  [dc comics, crime fighter, terrorist, secret i...
# 4     49529  [based on novel, mars, medallion, space travel...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
#                                                 cast                 crew  \
# 0  [Jake Sully, Neytiri, Dr. Grace Augustine, Col...      [James Cameron]
# 1  [Captain Jack Sparrow, Will Turner, Elizabeth ...     [Gore Verbinski]
# ...

# %%
#Now we have to remove spaces in between as kartik tiwari & kartik rastogi
#Now tags for both will be kartik as common now this will make our model less accurate

# def rem_spaces(lst):
#   lst1 = []
#   for i in lst:
#     i = i.replace(" " , "")
#     lst1.append(i)
#   return lst1

# rem_spaces(["Ac tion", "Adven  ture", "Fa ntasy", "Scie nceF ict ion"])

movies["genres"] = movies["genres"].apply(lambda x:[i.replace(" " , "") for i in x])
movies["cast"] = movies["cast"].apply(lambda x:[i.replace(" " , "") for i in x])
movies["crew"] = movies["crew"].apply(lambda x:[i.replace(" " , "") for i in x])
movies["keywords"] = movies["keywords"].apply(lambda x:[i.replace(" " , "") for i in x])

# %%
movies.head()
# Out:
#    movie_id                                           keywords  \
# 0     19995  [cultureclash, future, spacewar, spacecolony, ...
# 1       285  [ocean, drugabuse, exoticisland, eastindiatrad...
# 2    206647  [spy, basedonnovel, secretagent, sequel, mi6, ...
# 3     49026  [dccomics, crimefighter, terrorist, secretiden...
# 4     49529  [basedonnovel, mars, medallion, spacetravel, p...
#
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
# 1                  [Adventure, Fantasy, Action]
# 2                    [Action, Adventure, Crime]
# 3              [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, ScienceFiction]
#
#                                                 cast                crew  \
# 0  [JakeSully, Neytiri, Dr.GraceAugustine, Col.Qu...      [JamesCameron]
# 1  [CaptainJackSparrow, WillTurner, ElizabethSwan...     [GoreVerbinski]
# ...

# %%
movies["tags"] = movies["genres"] + movies["keywords"] + movies["cast"] + movies["crew"]

# %%
movies.head(1)
# Out:
#    movie_id                                           keywords  \
# 0     19995  [cultureclash, future, spacewar, spacecolony, ...
#
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
#
#                                                 cast            crew   title  \
# 0  [JakeSully, Neytiri, Dr.GraceAugustine, Col.Qu...  [JamesCameron]  Avatar
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
#
#                                                 tags
# 0  [Action, Adventure, Fantasy, ScienceFiction, c...

# %%
new_df = movies[["movie_id" , "title" , "tags"]]
new_df.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 tags
# 0  [Action, Adventure, Fantasy, ScienceFiction, c...
# 1  [Adventure, Fantasy, Action, ocean, drugabuse,...
# 2  [Action, Adventure, Crime, spy, basedonnovel, ...
# 3  [Action, Crime, Drama, Thriller, dccomics, cri...
# 4  [Action, Adventure, ScienceFiction, basedonnov...

# %%
#now we will convert out tags list to string

new_df["tags"] = new_df["tags"].apply(lambda x:" ".join(x))
# Out:
# <ipython-input-194-87c615ffc58a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["tags"] = new_df["tags"].apply(lambda x:" ".join(x))

# %%
# We have converted back to lower case all the charecters present at
new_df["tags"] = new_df["tags"].apply(lambda x:x.lower())
# Out:
# <ipython-input-195-955bc072b668>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["tags"] = new_df["tags"].apply(lambda x:x.lower())

# %%
new_df["tags"][0]
# Out:
# "action adventure fantasy sciencefiction cultureclash future spacewar spacecolony society spacetravel futuristic romance space alien tribe alienplanet cgi marine soldier battle loveaffair antiwar powerrelations mindandsoul 3d jakesully neytiri dr.graceaugustine col.quaritch trudychacon selfridge normspellman moat eytukan tsu'tey dr.maxpatel lylewainfleet privatefike cryovaultmedtech venturestarcrewchief lockuptrooper shuttlepilot shuttleco-pilot shuttlecrewchief tractoroperator/troupe dragongunshippilot dragongunshipgunner dragongunshipnavigator suit#1 suit#2 ambientroomtech ambientroomtech/troupe horseclanleader linkroomtech basketballavatar/troupe basketballavatar na'vichild troupe troupe troupe troupe troupe troupe troupe troupe troupe troupe troupe troupe opcenterstaff opcenterstaff opcenterstaff opcenterstaff opcenterstaff opcenterdutyofficer opcenterstaff dancer dancer dancer dancer dancer dancer dancer dancer dancer miningchief(uncredited) veteranminer(uncredited) richard(uncr
# ...

# %% [markdown]
# ##Now we are going to train our dataset

# %%
# stop words are words which are used for sentence formation but does not contribute to

from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(stop_words = "english" , max_features = 5000 )
cv.fit_transform(new_df["tags"]).toarray().shape
# Out:
# (4782, 5000)

# %%
import nltk
from nltk.stem.porter import PorterStemmer
port = PorterStemmer()
def stemming(text):
  lst = []
  for i in text.split():
    lst.append(port.stem(i))
  return " ".join(lst)

# %%
new_df["tags"] = new_df["tags"].apply(stemming)
# Out:
# <ipython-input-199-0ceaf6cb843c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["tags"] = new_df["tags"].apply(stemming)

# %%
cv = CountVectorizer(stop_words = "english" , max_features = 5000 )
vectors = cv.fit_transform(new_df["tags"]).toarray()

# %%
from sklearn.metrics.pairwise import cosine_similarity
similarity = cosine_similarity(vectors)
similarity[0]
# Out:
# array([1.        , 0.01958527, 0.20290787, ..., 0.01022807, 0.        ,
#        0.        ])

# %%
sorted(list(enumerate(similarity[2])),reverse = True , key = lambda x:x[:1])

# %%
def recommender_system(movie):
  movie_index = new_df[new_df['title'] == movie].index[0]
  distances = similarity[movie_index]
  movie_list = sorted(list(enumerate(distances)),reverse = True , key = lambda x:x[1])[0:6]
  for i in movie_list:
    print(new_df.iloc[i[0]].title , end = " , ")
recommender_system("Avatar")
# Out:
# Avatar , American Gangster , The Purge: Election Year , Casablanca , The Imitation Game , Spider-Man 3 ,
